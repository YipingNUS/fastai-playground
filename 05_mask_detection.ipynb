# %%
# run this if fastai isn't set up in your local or you're running from google colab.
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.vision.all import *

# %%
# dataset from this repo: https://github.com/chandrikadeb7/Face-Mask-Detection
path = Path('/storage/Face-Mask-Detection/dataset')

# %%
pets = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(seed=42),
                 get_y=parent_label,
                 item_tfms=Resize(460),
                 batch_tfms=aug_transforms(size=224, min_scale=0.75))
dls = pets.dataloaders(path)

# %%
dls.show_batch(nrows=1, ncols=3)

# %% [markdown]
# ## 1. Use fastai's default learning rates

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.343711</td>
#       <td>0.037153</td>
#       <td>0.014304</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
# ...

# %% [markdown]
# ## 2. Fine-tune the learning rates

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
lr_min,lr_steep = learn.lr_find()
# Out:
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2, base_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.294141</td>
#       <td>0.042559</td>
#       <td>0.013004</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# SuggestedLRs(lr_min=1.0964782268274575e-05, lr_steep=9.12010818865383e-07)

# %%
# train for many epochs and see when it starts to overfit
learn.fit_one_cycle(10, lr_max=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.020362</td>
#       <td>0.002232</td>
#       <td>0.001300</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.017430</td>
#       <td>0.001140</td>
#       <td>0.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011027</td>
#       <td>0.001706</td>
#       <td>0.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.011724</td>
#       <td>0.000681</td>
#       <td>0.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.010305</td>
#       <td>0.003921</td>
#       <td>0.001300</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
# train the final model with the best parameters
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2, base_lr=3e-3)
learn.unfreeze()
learn.fit_one_cycle(2, lr_max=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.287206</td>
#       <td>0.049566</td>
#       <td>0.015605</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
# ...

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(uploader.data[0])
img
# Out:
# PILImage mode=RGB size=300x168

# %%
pred,_,probs = learn.predict(img)
print(f"Prediction: {pred}")
print(f"Probability of wearing mask: {probs[0].item():.6f}")
# Out:
# Prediction: with_mask
# Probability of wearing mask: 1.000000

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(uploader.data[0])
img
# Out:
# PILImage mode=RGB size=290x174

# %%
pred,_,probs = learn.predict(img)
print(f"Prediction: {pred}")
print(f"Probability of wearing mask: {probs[0].item():.6f}")
# Out:
# Prediction: without_mask
# Probability of wearing mask: 0.000141
